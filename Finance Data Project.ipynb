# %%
from pandas_datareader import data, wb
import numpy as np
import pandas as pd
import seaborn as sns
import datetime 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %%
bac = data.DataReader("BAC",'yahoo',start, end)
cg = data.DataReader('C','yahoo',start,end)
gs = data.DataReader('GS','yahoo',start,end)
jc = data.DataReader('JPM','yahoo',start,end)
ms = data.DataReader('MS','yahoo',start,end)
wf = data.DataReader('WFC','yahoo',start,end)

# %%
jc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2006-01-03 to 2015-12-31
# Data columns (total 6 columns):
# High         2517 non-null float64
# Low          2517 non-null float64
# Open         2517 non-null float64
# Close        2517 non-null float64
# Volume       2517 non-null float64
# Adj Close    2517 non-null float64
# dtypes: float64(6)
# memory usage: 137.6 KB

# %%
df =data.DataReader(['BAC','C','GS','JPM','MS','WFC'],'yahoo',start, end)

# %%
df.head()
# Out:
# Attributes       High                                                \
# Symbols           BAC           C          GS        JPM         MS
# Date
# 2006-01-03  47.180000  493.799988  129.440002  40.360001  58.490002
# 2006-01-04  47.240002  491.000000  128.910004  40.139999  59.279999
# 2006-01-05  46.830002  487.799988  127.320000  39.810001  58.590000
# 2006-01-06  46.910000  489.000000  129.250000  40.240002  58.849998
# 2006-01-09  46.970001  487.399994  130.619995  40.720001  59.290001
#
# Attributes                   Low                                     ...  \
# Symbols           WFC        BAC           C          GS        JPM  ...
# Date                                                                 ...
# 2006-01-03  31.975000  46.150002  481.100006  124.230003  39.299999  ...
# 2006-01-04  31.820000  46.450001  483.500000  126.379997  39.419998  ...
# 2006-01-05  31.555000  46.320000  484.000000  125.610001  39.500000  ...
# ...

# %%
tickers = ['Bank of America','CitiGroup','Goldman Sachs','JPMorgan Chase','Morgan Stanley','Wells Fargo']

# %%
tickers
# Out:
# ['Bank of America',
#  'CitiGroup',
#  'Goldman Sachs',
#  'JPMorgan Chase',
#  'Morgan Stanley',
#  'Wells Fargo']

# %%
bank_stocks = pd.concat([bac,cg,gs,jc,ms,wf],axis=1, keys=tickers)

# %%
bank_stocks.head()
# Out:
#            Bank of America                                               \
#                       High        Low       Open      Close      Volume
# Date
# 2006-01-03       47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04       47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05       46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06       46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09       46.970001  46.360001  46.720001  46.599998  15619400.0
#
#                         CitiGroup                                      ...  \
#             Adj Close        High         Low        Open       Close  ...
# Date                                                                   ...
# 2006-01-03  35.953278  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04  35.571438  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05  35.617275  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %%
bank_stocks.columns.names = ['Bank Ticker', 'Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker Bank of America                                               \
# Stock Info             High        Low       Open      Close      Volume
# Date
# 2006-01-03        47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04        47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05        46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06        46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09        46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker              CitiGroup                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   35.953278  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   35.571438  491.000000  483.500000  488.600006  483.799988  ...
# ...

# %%
bank_stocks.xs(key='Close', axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# Bank of America     54.900002
# CitiGroup          564.099976
# Goldman Sachs      247.919998
# JPMorgan Chase      70.080002
# Morgan Stanley      89.300003
# Wells Fargo         58.520000
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
bank_stocks.pct_change().head()
# Out:
# Bank Ticker Bank of America                                                    \
# Stock Info             High       Low      Open     Close    Volume Adj Close
# Date
# 2006-01-03              NaN       NaN       NaN       NaN       NaN       NaN
# 2006-01-04         0.001272  0.006501  0.001705 -0.010620  0.089662 -0.010620
# 2006-01-05        -0.008679 -0.002799 -0.008936  0.001288 -0.156955  0.001289
# 2006-01-06         0.001708  0.000648  0.004723 -0.001501 -0.158369 -0.001501
# 2006-01-09         0.001279  0.000216 -0.001709  0.000644  0.239655  0.000645
#
# Bank Ticker CitiGroup                                ... Morgan Stanley  \
# Stock Info       High       Low      Open     Close  ...           Open
# Date                                                 ...
# 2006-01-03        NaN       NaN       NaN       NaN  ...            NaN
# 2006-01-04  -0.005670  0.004989 -0.002857 -0.018462  ...       0.026762
# ...

# %%
bank_stocks['BAC']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BAC'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-8905650411aa> in <module>
# ----> 1 bank_stocks['BAC']
#
# ...

# %%
for tick in tickers:
    returns[tick +'>Return'] = bank_stocks[tick]['Close'].pct_change()
    
returns.head()

# %%
sns.pairplot(returns[1:])

# %%
returns.idxmin()

# %%
returns.idxmax()

# %%
returns.std()

# %%
returns.ix['2015-01-01':'2015-12-30'].std()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Series([], dtype: float64)

# %%
sns.distplot(returns.ix['2015-01-01':'2015-12-31']['MS Return'],color='purple', bins=100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
sns.distplot(returns)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:198: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:893: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-15137553aeca> in <module>
#       6 # Optional Plotly Method Imports
#       7 import plotly
# ----> 8 import cufflinks as cf
#       9 cf.go_offline()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cufflinks\__init__.py in <module>
#      13 from . import datagen
#      14 from . import helper
# ---> 15 from . import tools
#      16 from . import colors
#      17 from . import pandastools
#
# C:\ProgramData\Anaconda3\lib\site-packages\cufflinks\tools.py in <module>
#       4 import pandas as pd
#       5 import plotly.offline as py_offline
# ----> 6 import plotly.plotly as py
#       7 import plotly.graph_objs as go
#       8
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\plotly\__init__.py in <module>
#       2 from _plotly_future_ import _chart_studio_error
#       3
# ...

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(15,5),label = tick)
plt.legend()

# %%
sns.heatmap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True)

# %%
sns.clustermap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True)

# %%
plt.figure(figsize=(12,6))
bac['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
bac['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC CLOSE')
plt.legend()
