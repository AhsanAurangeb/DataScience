# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\Ahsan Zeb\\Downloads\\Refactored_Py_DS_ML_Bootcamp-master\\07-Pandas-Built-in-Data-Viz'

# %%
cd ..
# Out:
# C:\Users\Ahsan Zeb\Downloads\Refactored_Py_DS_ML_Bootcamp-master

# %%
cd 07-Pandas-Built-in-Data-Viz
# Out:
# C:\Users\Ahsan Zeb\Downloads\Refactored_Py_DS_ML_Bootcamp-master\07-Pandas-Built-in-Data-Viz

# %%
df1 = pd.read_csv('df1')
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df['A'].hist()
plt.style.use('ggplot')

# %%
plt.style.use('bmh')
df1['A'].hist()

# %%
plt.style.use('dark_background')
df1['A'].hist()

# %%
plt.style.use('ggplot')

# %% [markdown]
# # Area

# %%
df2.plot.area(alpha=0.4)

# %% [markdown]
# # Barplot

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %% [markdown]
# # Histogram

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.plot.line(y='B',figsize=(12,3),lw=1)

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Purples')

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()

# %% [markdown]
# # Exercise

# %%
df3 = pd.read_csv('df3')

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a',y='b', figsize=(15,3), color='red',s=100)

# %%
df3['a'].plot.hist(color='blue')

# %%
df3['a'].plot.hist(color='blue', bins=30)
plt.style.use('ggplot')

# %%
df3['d'].plot.kde()

# %%
df3[['a','b']].plot.box()

# %%
df3['d'].plot.kde(ls='--',lw=5)

# %%
df3.iloc[0:31].plot.area(alpha=0.5)

# %%
df3.iloc[0:31].plot.area(alpha=0.5)
plt.legend(bbox_to_anchor=(1, 0.7))
